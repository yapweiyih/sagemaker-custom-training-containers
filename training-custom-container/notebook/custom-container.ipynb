# %% [markdown]
# <h1>Script-mode Custom Training Container</h1>

# %% [markdown]
# This notebook demonstrates how to build and use a custom Docker container for training with Amazon SageMaker that leverages on the <strong>Script Mode</strong> execution that is implemented by the sagemaker-containers library. Reference documentation is available at https://github.com/aws/sagemaker-containers

# %% [markdown]
# We start by defining some variables like the current execution role, the ECR repository that we are going to use for pushing the custom Docker container and a default Amazon S3 bucket to be used by Amazon SageMaker.

# %%
import boto3
import sagemaker
from sagemaker import get_execution_role

ecr_namespace = 'sagemaker-training-containers/'
prefix = 'script-mode-container'

ecr_repository_name = ecr_namespace + prefix
role = "arn:aws:iam::342474125894:role/service-role/AmazonSageMaker-ExecutionRole-20190405T234154"
account_id = role.split(':')[4]
region = boto3.Session().region_name
sagemaker_session = sagemaker.session.Session()
bucket = sagemaker_session.default_bucket()

print("account_id", account_id)
print("region", region)
print("role", role)
print("bucket", bucket)
print("ecr_repository_name", ecr_repository_name)
# Out:
# account_id 342474125894
# region ap-southeast-1
# role arn:aws:iam::342474125894:role/service-role/AmazonSageMaker-ExecutionRole-20190405T234154
# bucket sagemaker-ap-southeast-1-342474125894
# ecr_repository_name sagemaker-training-containers/script-mode-container

# %% [markdown]
# <h3>Build and push the container</h3>
# We are now ready to build this container and push it to Amazon ECR. This task is executed using a shell script stored in the ../script/ folder. Let's take a look at this script and then execute it.

# %%
! ../scripts/build_and_push.sh $account_id $region $ecr_repository_name
# Out:
# [5/9] RUN ln -s $(which python3) /usr/local/bin/python                 0.3s
#  => [6/9] RUN pip3 install --no-cache --upgrade     numpy==1.14.5     pa  28.0s
#  => [7/9] RUN pip3 install --no-cache --upgrade     sagemaker-container  146.8s
#  => [8/9] COPY code/* /opt/ml/code/                                        0.1s
#  => exporting to image                                                    11.0s
#  => => exporting layers                                                   11.0s
# [+] Building 980.5s (13/14)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 2.27kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:16.04            2.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/9] FROM docker.io/library/ubuntu:16.04@sha256:3355b6e4ba1b1  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [2/9] RUN apt-get update && apt-get install -y --no-install-recomme  538.5s
#  => [3/9] RUN wget https://www.python.org/ftp/python/3.6.6/Python-3.6.6  249.2s
#  => [4/9] RUN pip3 --no-cache-dir install --upgrade pip                    3.9s
#  => [5/9] RUN ln -s $(which python3) /usr/local/bin/python                 0.3s
#  => [6/9] RUN pip3 install --no-cache --upgrade     numpy==1.14.5     pa  28.0s
#  => [7/9] RUN pip3 install --no-cache --upgrade     sagemaker-container  146.8s
#  => [8/9] COPY code/* /opt/ml/code/                                        0.1s
#  => exporting to image                                                    11.2s
#  => => exporting layers                                                   11.2s
# [+] Building 980.6s (13/14)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 2.27kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:16.04            2.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/9] FROM docker.io/library/ubuntu:16.04@sha256:3355b6e4ba1b1  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [2/9] RUN apt-get update && apt-get install -y --no-install-recomme  538.5s
#  => [3/9] RUN wget https://www.python.org/ftp/python/3.6.6/Python-3.6.6  249.2s
#  => [4/9] RUN pip3 --no-cache-dir install --upgrade pip                    3.9s
#  => [5/9] RUN ln -s $(which python3) /usr/local/bin/python                 0.3s
#  => [6/9] RUN pip3 install --no-cache --upgrade     numpy==1.14.5     pa  28.0s
#  => [7/9] RUN pip3 install --no-cache --upgrade     sagemaker-container  146.8s
#  => [8/9] COPY code/* /opt/ml/code/                                        0.1s
#  => exporting to image                                                    11.3s
#  => => exporting layers                                                   11.3s
# [+] Building 980.8s (13/14)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 2.27kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:16.04            2.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/9] FROM docker.io/library/ubuntu:16.04@sha256:3355b6e4ba1b1  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [2/9] RUN apt-get update && apt-get install -y --no-install-recomme  538.5s
#  => [3/9] RUN wget https://www.python.org/ftp/python/3.6.6/Python-3.6.6  249.2s
#  => [4/9] RUN pip3 --no-cache-dir install --upgrade pip                    3.9s
#  => [5/9] RUN ln -s $(which python3) /usr/local/bin/python                 0.3s
#  => [6/9] RUN pip3 install --no-cache --upgrade     numpy==1.14.5     pa  28.0s
#  => [7/9] RUN pip3 install --no-cache --upgrade     sagemaker-container  146.8s
#  => [8/9] COPY code/* /opt/ml/code/                                        0.1s
#  => exporting to image                                                    11.5s
#  => => exporting layers                                                   11.5s
# [+] Building 980.9s (13/14)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 2.27kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:16.04            2.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/9] FROM docker.io/library/ubuntu:16.04@sha256:3355b6e4ba1b1  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [2/9] RUN apt-get update && apt-get install -y --no-install-recomme  538.5s
#  => [3/9] RUN wget https://www.python.org/ftp/python/3.6.6/Python-3.6.6  249.2s
#  => [4/9] RUN pip3 --no-cache-dir install --upgrade pip                    3.9s
#  => [5/9] RUN ln -s $(which python3) /usr/local/bin/python                 0.3s
#  => [6/9] RUN pip3 install --no-cache --upgrade     numpy==1.14.5     pa  28.0s
#  => [7/9] RUN pip3 install --no-cache --upgrade     sagemaker-container  146.8s
#  => [8/9] COPY code/* /opt/ml/code/                                        0.1s
#  => exporting to image                                                    11.6s
#  => => exporting layers                                                   11.6s
# [+] Building 981.1s (13/14)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 2.27kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:16.04            2.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/9] FROM docker.io/library/ubuntu:16.04@sha256:3355b6e4ba1b1  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [2/9] RUN apt-get update && apt-get install -y --no-install-recomme  538.5s
#  => [3/9] RUN wget https://www.python.org/ftp/python/3.6.6/Python-3.6.6  249.2s
#  => [4/9] RUN pip3 --no-cache-dir install --upgrade pip                    3.9s
#  => [5/9] RUN ln -s $(which python3) /usr/local/bin/python                 0.3s
#  => [6/9] RUN pip3 install --no-cache --upgrade     numpy==1.14.5     pa  28.0s
#  => [7/9] RUN pip3 install --no-cache --upgrade     sagemaker-container  146.8s
#  => [8/9] COPY code/* /opt/ml/code/                                        0.1s
#  => exporting to image                                                    11.8s
#  => => exporting layers                                                   11.8s
# [+] Building 981.2s (13/14)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 2.27kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:16.04            2.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/9] FROM docker.io/library/ubuntu:16.04@sha256:3355b6e4ba1b1  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [2/9] RUN apt-get update && apt-get install -y --no-install-recomme  538.5s
#  => [3/9] RUN wget https://www.python.org/ftp/python/3.6.6/Python-3.6.6  249.2s
#  => [4/9] RUN pip3 --no-cache-dir install --upgrade pip                    3.9s
#  => [5/9] RUN ln -s $(which python3) /usr/local/bin/python                 0.3s
#  => [6/9] RUN pip3 install --no-cache --upgrade     numpy==1.14.5     pa  28.0s
#  => [7/9] RUN pip3 install --no-cache --upgrade     sagemaker-container  146.8s
#  => [8/9] COPY code/* /opt/ml/code/                                        0.1s
#  => exporting to image                                                    11.9s
#  => => exporting layers                                                   11.9s
# [+] Building 981.4s (13/14)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 2.27kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:16.04            2.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/9] FROM docker.io/library/ubuntu:16.04@sha256:3355b6e4ba1b1  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [2/9] RUN apt-get update && apt-get install -y --no-install-recomme  538.5s
#  => [3/9] RUN wget https://www.python.org/ftp/python/3.6.6/Python-3.6.6  249.2s
#  => [4/9] RUN pip3 --no-cache-dir install --upgrade pip                    3.9s
#  => [5/9] RUN ln -s $(which python3) /usr/local/bin/python                 0.3s
#  => [6/9] RUN pip3 install --no-cache --upgrade     numpy==1.14.5     pa  28.0s
#  => [7/9] RUN pip3 install --no-cache --upgrade     sagemaker-container  146.8s
#  => [8/9] COPY code/* /opt/ml/code/                                        0.1s
#  => exporting to image                                                    12.1s
#  => => exporting layers                                                   12.1s
# [+] Building 981.5s (13/14)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 2.27kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:16.04            2.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/9] FROM docker.io/library/ubuntu:16.04@sha256:3355b6e4ba1b1  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [2/9] RUN apt-get update && apt-get install -y --no-install-recomme  538.5s
#  => [3/9] RUN wget https://www.python.org/ftp/python/3.6.6/Python-3.6.6  249.2s
#  => [4/9] RUN pip3 --no-cache-dir install --upgrade pip                    3.9s
#  => [5/9] RUN ln -s $(which python3) /usr/local/bin/python                 0.3s
#  => [6/9] RUN pip3 install --no-cache --upgrade     numpy==1.14.5     pa  28.0s
#  => [7/9] RUN pip3 install --no-cache --upgrade     sagemaker-container  146.8s
#  => [8/9] COPY code/* /opt/ml/code/                                        0.1s
#  => exporting to image                                                    12.2s
#  => => exporting layers                                                   12.2s
# [+] Building 981.7s (13/14)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 2.27kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:16.04            2.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/9] FROM docker.io/library/ubuntu:16.04@sha256:3355b6e4ba1b1  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [2/9] RUN apt-get update && apt-get install -y --no-install-recomme  538.5s
#  => [3/9] RUN wget https://www.python.org/ftp/python/3.6.6/Python-3.6.6  249.2s
#  => [4/9] RUN pip3 --no-cache-dir install --upgrade pip                    3.9s
#  => [5/9] RUN ln -s $(which python3) /usr/local/bin/python                 0.3s
#  => [6/9] RUN pip3 install --no-cache --upgrade     numpy==1.14.5     pa  28.0s
#  => [7/9] RUN pip3 install --no-cache --upgrade     sagemaker-container  146.8s
#  => [8/9] COPY code/* /opt/ml/code/                                        0.1s
#  => exporting to image                                                    12.4s
#  => => exporting layers                                                   12.4s
# [+] Building 981.8s (14/14) FINISHED
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 2.27kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:16.04            2.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/9] FROM docker.io/library/ubuntu:16.04@sha256:3355b6e4ba1b1  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [2/9] RUN apt-get update && apt-get install -y --no-install-recomme  538.5s
#  => [3/9] RUN wget https://www.python.org/ftp/python/3.6.6/Python-3.6.6  249.2s
#  => [4/9] RUN pip3 --no-cache-dir install --upgrade pip                    3.9s
#  => [5/9] RUN ln -s $(which python3) /usr/local/bin/python                 0.3s
#  => [6/9] RUN pip3 install --no-cache --upgrade     numpy==1.14.5     pa  28.0s
#  => [7/9] RUN pip3 install --no-cache --upgrade     sagemaker-container  146.8s
#  => [8/9] COPY code/* /opt/ml/code/                                        0.1s
#  => exporting to image                                                    12.4s
#  => => exporting layers                                                   12.4s
#  => => writing image sha256:9567b514681ddf6e82397f4548ba122cd178711a7d23f  0.0s
#  => => naming to docker.io/sagemaker-training-containers/script-mode-cont  0.0s
# + docker tag sagemaker-training-containers/script-mode-container 342474125894.dkr.ecr.ap-southeast-1.amazonaws.com/sagemaker-training-containers/script-mode-container:latest
# + SERVER=342474125894.dkr.ecr.ap-southeast-1.amazonaws.com
# + aws ecr get-login-password
# + docker login --username AWS --password-stdin 342474125894.dkr.ecr.ap-southeast-1.amazonaws.com
# Login Succeeded
# + echo '***Create Repo***'
# ***Create Repo***
# + aws ecr describe-repositories --repository-names sagemaker-training-containers/script-mode-container
# {
#     "repositories": [
#         {
#             "repositoryArn": "arn:aws:ecr:ap-southeast-1:342474125894:repository/sagemaker-training-containers/script-mode-container",
#             "registryId": "342474125894",
#             "repositoryName": "sagemaker-training-containers/script-mode-container",
#             "repositoryUri": "342474125894.dkr.ecr.ap-southeast-1.amazonaws.com/sagemaker-training-containers/script-mode-container",
#             "createdAt": "2020-08-11T20:05:43+08:00",
#             "imageTagMutability": "MUTABLE",
#             "imageScanningConfiguration": {
#                 "scanOnPush": false
#             },
#             "encryptionConfiguration": {
#                 "encryptionType": "AES256"
#             }
#         }
#     ]
# }
# + echo '***Push to Repo***'
# ***Push to Repo***
# + docker push 342474125894.dkr.ecr.ap-southeast-1.amazonaws.com/sagemaker-training-containers/script-mode-container:latest
# The push refers to repository [342474125894.dkr.ecr.ap-southeast-1.amazonaws.com/sagemaker-training-containers/script-mode-container]
#
#
#
#
#
#
#
#
#
#
#
# latest: digest: sha256:608a1d263bcdd71fb72991b7d1abe08ac04687ddd869ff74bfe0de4a6b138c82 size: 2625

# %% [markdown]
# <h3>Training with Amazon SageMaker</h3>
#
# Once we have correctly pushed our container to Amazon ECR, we are ready to start training with Amazon SageMaker, which requires the ECR path to the Docker container used for training as parameter for starting a training job.

# %%
container_image_uri = '{0}.dkr.ecr.{1}.amazonaws.com/{2}:latest'.format(account_id, region, ecr_repository_name)
print(container_image_uri)
# Out:
# 342474125894.dkr.ecr.ap-southeast-1.amazonaws.com/sagemaker-training-containers/script-mode-container:latest

# %%
! echo "val1, val2, val3" > dummy.csv
print(sagemaker_session.upload_data('dummy.csv', bucket, prefix + '/train'))
print(sagemaker_session.upload_data('dummy.csv', bucket, prefix + '/val'))
! rm dummy.csv
# Out:
# s3://sagemaker-ap-southeast-1-342474125894/script-mode-container/train/dummy.csv
# s3://sagemaker-ap-southeast-1-342474125894/script-mode-container/val/dummy.csv

# %% [markdown]
# Finally, we can execute the training job by calling the fit() method of the generic Estimator object defined in the Amazon SageMaker Python SDK (https://github.com/aws/sagemaker-python-sdk/blob/master/src/sagemaker/estimator.py). This corresponds to calling the CreateTrainingJob() API (https://docs.aws.amazon.com/sagemaker/latest/dg/API_CreateTrainingJob.html).

# %%
import sagemaker
import json

# JSON encode hyperparameters to avoid showing some info messages raised by the sagemaker-containers library.
def json_encode_hyperparameters(hyperparameters):
    return {str(k): json.dumps(v) for (k, v) in hyperparameters.items()}

hyperparameters = json_encode_hyperparameters({
    "hp1": "value1",
    "hp2": 300,
    "hp3": 0.001})

est = sagemaker.estimator.Estimator(container_image_uri,
                                    role, 
                                    instance_count=1, 
                                    instance_type='local', # we use local mode
                                    #instance_type='ml.m5.xlarge',
                                    base_job_name=prefix,
                                    hyperparameters=hyperparameters)

train_config = sagemaker.session.s3_input('s3://{0}/{1}/train/'.format(bucket, prefix), content_type='text/csv')
val_config = sagemaker.session.s3_input('s3://{0}/{1}/val/'.format(bucket, prefix), content_type='text/csv')

est.fit({'train': train_config, 'validation': val_config })
# Out:
# The class sagemaker.session.s3_input has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The class sagemaker.session.s3_input has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Creating tmptraqfog4_algo-1-1dexd_1 ...
# Attaching to tmptraqfog4_algo-1-1dexd_1
# algo-1-1dexd_1  | 2021-01-04 07:30:40,259 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-1dexd_1  | 2021-01-04 07:30:40,299 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-1dexd_1  | 2021-01-04 07:30:40,322 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-1dexd_1  | 2021-01-04 07:30:40,336 sagemaker-containers INFO     Invoking user script
# algo-1-1dexd_1  |
# algo-1-1dexd_1  | Training Env:
# algo-1-1dexd_1  |
# algo-1-1dexd_1  | {
# algo-1-1dexd_1  |     "additional_framework_parameters": {},
# algo-1-1dexd_1  |     "channel_input_dirs": {
# algo-1-1dexd_1  |         "train": "/opt/ml/input/data/train",
# algo-1-1dexd_1  |         "validation": "/opt/ml/input/data/validation"
# algo-1-1dexd_1  |     },
# algo-1-1dexd_1  |     "current_host": "algo-1-1dexd",
# algo-1-1dexd_1  |     "framework_module": null,
# algo-1-1dexd_1  |     "hosts": [
# algo-1-1dexd_1  |         "algo-1-1dexd"
# algo-1-1dexd_1  |     ],
# algo-1-1dexd_1  |     "hyperparameters": {
# algo-1-1dexd_1  |         "hp1": "value1",
# algo-1-1dexd_1  |         "hp2": 300,
# algo-1-1dexd_1  |         "hp3": 0.001
# algo-1-1dexd_1  |     },
# algo-1-1dexd_1  |     "input_config_dir": "/opt/ml/input/config",
# algo-1-1dexd_1  |     "input_data_config": {
# algo-1-1dexd_1  |         "train": {
# algo-1-1dexd_1  |             "TrainingInputMode": "File",
# algo-1-1dexd_1  |             "ContentType": "text/csv"
# algo-1-1dexd_1  |         },
# algo-1-1dexd_1  |         "validation": {
# algo-1-1dexd_1  |             "TrainingInputMode": "File",
# algo-1-1dexd_1  |             "ContentType": "text/csv"
# algo-1-1dexd_1  |         }
# algo-1-1dexd_1  |     },
# algo-1-1dexd_1  |     "input_dir": "/opt/ml/input",
# algo-1-1dexd_1  |     "is_master": true,
# algo-1-1dexd_1  |     "job_name": "script-mode-container-2021-01-04-07-30-35-367",
# algo-1-1dexd_1  |     "log_level": 20,
# algo-1-1dexd_1  |     "master_hostname": "algo-1-1dexd",
# algo-1-1dexd_1  |     "model_dir": "/opt/ml/model",
# algo-1-1dexd_1  |     "module_dir": "/opt/ml/code",
# algo-1-1dexd_1  |     "module_name": "train",
# algo-1-1dexd_1  |     "network_interface_name": "eth0",
# algo-1-1dexd_1  |     "num_cpus": 4,
# algo-1-1dexd_1  |     "num_gpus": 0,
# algo-1-1dexd_1  |     "output_data_dir": "/opt/ml/output/data",
# algo-1-1dexd_1  |     "output_dir": "/opt/ml/output",
# algo-1-1dexd_1  |     "output_intermediate_dir": "/opt/ml/output/intermediate",
# algo-1-1dexd_1  |     "resource_config": {
# algo-1-1dexd_1  |         "current_host": "algo-1-1dexd",
# algo-1-1dexd_1  |         "hosts": [
# algo-1-1dexd_1  |             "algo-1-1dexd"
# algo-1-1dexd_1  |         ]
# algo-1-1dexd_1  |     },
# algo-1-1dexd_1  |     "user_entry_point": "train.py"
# algo-1-1dexd_1  | }
# algo-1-1dexd_1  |
# algo-1-1dexd_1  | Environment variables:
# algo-1-1dexd_1  |
# algo-1-1dexd_1  | SM_HOSTS=["algo-1-1dexd"]
# algo-1-1dexd_1  | SM_NETWORK_INTERFACE_NAME=eth0
# algo-1-1dexd_1  | SM_HPS={"hp1":"value1","hp2":300,"hp3":0.001}
# algo-1-1dexd_1  | SM_USER_ENTRY_POINT=train.py
# algo-1-1dexd_1  | SM_FRAMEWORK_PARAMS={}
# algo-1-1dexd_1  | SM_RESOURCE_CONFIG={"current_host":"algo-1-1dexd","hosts":["algo-1-1dexd"]}
# algo-1-1dexd_1  | SM_INPUT_DATA_CONFIG={"train":{"ContentType":"text/csv","TrainingInputMode":"File"},"validation":{"ContentType":"text/csv","TrainingInputMode":"File"}}
# algo-1-1dexd_1  | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# algo-1-1dexd_1  | SM_CHANNELS=["train","validation"]
# algo-1-1dexd_1  | SM_CURRENT_HOST=algo-1-1dexd
# algo-1-1dexd_1  | SM_MODULE_NAME=train
# algo-1-1dexd_1  | SM_LOG_LEVEL=20
# algo-1-1dexd_1  | SM_FRAMEWORK_MODULE=
# algo-1-1dexd_1  | SM_INPUT_DIR=/opt/ml/input
# algo-1-1dexd_1  | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# algo-1-1dexd_1  | SM_OUTPUT_DIR=/opt/ml/output
# algo-1-1dexd_1  | SM_NUM_CPUS=4
# algo-1-1dexd_1  | SM_NUM_GPUS=0
# algo-1-1dexd_1  | SM_MODEL_DIR=/opt/ml/model
# algo-1-1dexd_1  | SM_MODULE_DIR=/opt/ml/code
# algo-1-1dexd_1  | SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train","validation":"/opt/ml/input/data/validation"},"current_host":"algo-1-1dexd","framework_module":null,"hosts":["algo-1-1dexd"],"hyperparameters":{"hp1":"value1","hp2":300,"hp3":0.001},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"ContentType":"text/csv","TrainingInputMode":"File"},"validation":{"ContentType":"text/csv","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"script-mode-container-2021-01-04-07-30-35-367","log_level":20,"master_hostname":"algo-1-1dexd","model_dir":"/opt/ml/model","module_dir":"/opt/ml/code","module_name":"train","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1-1dexd","hosts":["algo-1-1dexd"]},"user_entry_point":"train.py"}
# algo-1-1dexd_1  | SM_USER_ARGS=["--hp1","value1","--hp2","300","--hp3","0.001"]
# algo-1-1dexd_1  | SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# algo-1-1dexd_1  | SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# algo-1-1dexd_1  | SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# algo-1-1dexd_1  | SM_HP_HP1=value1
# algo-1-1dexd_1  | SM_HP_HP2=300
# algo-1-1dexd_1  | SM_HP_HP3=0.001
# algo-1-1dexd_1  | PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python36.zip:/usr/local/lib/python3.6:/usr/local/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/site-packages
# algo-1-1dexd_1  |
# algo-1-1dexd_1  | Invoking script with the following command:
# algo-1-1dexd_1  |
# algo-1-1dexd_1  | /usr/local/bin/python3.6 train.py --hp1 value1 --hp2 300 --hp3 0.001
# algo-1-1dexd_1  |
# algo-1-1dexd_1  |
# algo-1-1dexd_1  |
# algo-1-1dexd_1  | List of files in train channel:
# algo-1-1dexd_1  | /opt/ml/input/data/train/dummy.csv
# algo-1-1dexd_1  |
# algo-1-1dexd_1  | List of files in validation channel:
# algo-1-1dexd_1  | /opt/ml/input/data/validation/dummy.csv
# algo-1-1dexd_1  |
# algo-1-1dexd_1  | Running epoch 0...
# algo-1-1dexd_1  | Completed epoch 0.
# algo-1-1dexd_1  |
# algo-1-1dexd_1  | Running epoch 1...
# algo-1-1dexd_1  | Completed epoch 1.
# algo-1-1dexd_1  |
# algo-1-1dexd_1  | Running epoch 2...
# algo-1-1dexd_1  | Completed epoch 2.
# algo-1-1dexd_1  |
# algo-1-1dexd_1  | Running epoch 3...
# algo-1-1dexd_1  | Completed epoch 3.
# algo-1-1dexd_1  |
# algo-1-1dexd_1  | Running epoch 4...
# algo-1-1dexd_1  | Completed epoch 4.
# algo-1-1dexd_1  | 2021-01-04 07:30:45,410 sagemaker-containers INFO     Reporting training SUCCESS
# tmptraqfog4_algo-1-1dexd_1 exited with code 0
# Aborting on container exit...
# ===== Job Complete =====
