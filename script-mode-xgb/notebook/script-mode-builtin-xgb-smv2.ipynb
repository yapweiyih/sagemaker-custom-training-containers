# %% [markdown]
# ## Train xgboost using sagemaker local mode + buildin container

# %%
from sagemaker import get_execution_role
from sagemaker.xgboost.estimator import XGBoost
import sagemaker

role = "arn:aws:iam::342474125894:role/service-role/AmazonSageMaker-ExecutionRole-20190405T234154"

sagemaker_session = sagemaker.session.Session()

bucket = sagemaker_session.default_bucket()
prefix = 'script-mode-container-xgb'

# %%
train_config = sagemaker.inputs.TrainingInput('s3://{0}/{1}/train/'.format(bucket, prefix), content_type='text/csv')
val_config = sagemaker.inputs.TrainingInput('s3://{0}/{1}/val/'.format(bucket, prefix), content_type='text/csv')
print(train_config.config)
print(val_config.config)
# Out:
# {'DataSource': {'S3DataSource': {'S3DataType': 'S3Prefix', 'S3Uri': 's3://sagemaker-ap-southeast-1-342474125894/script-mode-container-xgb/train/', 'S3DataDistributionType': 'FullyReplicated'}}, 'ContentType': 'text/csv'}
# {'DataSource': {'S3DataSource': {'S3DataType': 'S3Prefix', 'S3Uri': 's3://sagemaker-ap-southeast-1-342474125894/script-mode-container-xgb/val/', 'S3DataDistributionType': 'FullyReplicated'}}, 'ContentType': 'text/csv'}

# %%
hyperparameters = {'hp1':'str1',
                   'hp2': 2,
                   'hp3': 0.1}

xgb_estimator = XGBoost(
    entry_point="train.py",
    source_dir="../docker/code",
    hyperparameters=hyperparameters,
    role=role,
    instance_count=1,
    #instance_type='local', 
    instance_type="ml.m5.2xlarge",
    framework_version="1.0-1",
)

# %%
xgb_estimator.fit({'train': train_config, 'validation': val_config })
# Out:
# 2020-08-20 06:42:32 Starting - Starting the training job...
# 2020-08-20 06:42:34 Starting - Launching requested ML instances......
# 2020-08-20 06:43:43 Starting - Preparing the instances for training...
# 2020-08-20 06:44:21 Downloading - Downloading input data
# 2020-08-20 06:44:21 Training - Downloading the training image...
# 2020-08-20 06:45:01 Uploading - Uploading generated training modelINFO:sagemaker-containers:Imported framework sagemaker_xgboost_container.training
# INFO:sagemaker-containers:No GPUs detected (normal if no gpus installed)
# INFO:sagemaker_xgboost_container.training:Invoking user training script.
# INFO:sagemaker-containers:Module train does not provide a setup.py.
# Generating setup.py
# INFO:sagemaker-containers:Generating setup.cfg
# INFO:sagemaker-containers:Generating MANIFEST.in
# INFO:sagemaker-containers:Installing module with the following command:
# /miniconda3/bin/python -m pip install .
# Processing /opt/ml/code
# Building wheels for collected packages: train
#   Building wheel for train (setup.py): started
#   Building wheel for train (setup.py): finished with status 'done'
#   Created wheel for train: filename=train-1.0.0-py2.py3-none-any.whl size=9230 sha256=b5615e4271623f77d45b3e44c7ff9a73b34ecb1f6c3c59a0b37aee95fb839e5e
#   Stored in directory: /home/model-server/tmp/pip-ephem-wheel-cache-_s2qu0u4/wheels/95/c1/85/65aaf48b35aba88c6e896d2fd04a4b69f1cee0d81ea32993ca
# Successfully built train
# Installing collected packages: train
# Successfully installed train-1.0.0
# INFO:sagemaker-containers:No GPUs detected (normal if no gpus installed)
# INFO:sagemaker-containers:Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "validation": "/opt/ml/input/data/validation",
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_xgboost_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "hp1": "str1",
#         "hp3": 0.1,
#         "hp2": 2
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "validation": {
#             "ContentType": "text/csv",
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train": {
#             "ContentType": "text/csv",
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "sagemaker-xgboost-2020-08-20-06-42-38-303",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-ap-southeast-1-342474125894/sagemaker-xgboost-2020-08-20-06-42-38-303/source/sourcedir.tar.gz",
#     "module_name": "train",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"hp1":"str1","hp2":2,"hp3":0.1}
# SM_USER_ENTRY_POINT=train.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"train":{"ContentType":"text/csv","RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"ContentType":"text/csv","RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train","validation"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_xgboost_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-ap-southeast-1-342474125894/sagemaker-xgboost-2020-08-20-06-42-38-303/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train","validation":"/opt/ml/input/data/validation"},"current_host":"algo-1","framework_module":"sagemaker_xgboost_container.training:main","hosts":["algo-1"],"hyperparameters":{"hp1":"str1","hp2":2,"hp3":0.1},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"ContentType":"text/csv","RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"ContentType":"text/csv","RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"sagemaker-xgboost-2020-08-20-06-42-38-303","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-ap-southeast-1-342474125894/sagemaker-xgboost-2020-08-20-06-42-38-303/source/sourcedir.tar.gz","module_name":"train","network_interface_name":"eth0","num_cpus":8,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"train.py"}
# SM_USER_ARGS=["--hp1","str1","--hp2","2","--hp3","0.1"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_HP1=str1
# SM_HP_HP3=0.1
# SM_HP_HP2=2
# PYTHONPATH=/miniconda3/bin:/:/miniconda3/lib/python3.6/site-packages/xgboost/dmlc-core/tracker:/miniconda3/lib/python36.zip:/miniconda3/lib/python3.6:/miniconda3/lib/python3.6/lib-dynload:/miniconda3/lib/python3.6/site-packages
#
# Invoking script with the following command:
#
# /miniconda3/bin/python -m train --hp1 str1 --hp2 2 --hp3 0.1
#
#
# Namespace(hp1='str1', hp2=2, hp3=0.1, model_dir='/opt/ml/model', train='/opt/ml/input/data/train', validation='/opt/ml/input/data/validation')
#
# List of files in train channel:
# /opt/ml/input/data/train/train.csv
#
# List of files in validation channel:
# /opt/ml/input/data/validation/test.csv
# X_train: (70, 5), y_train:(70,)
# X_test: (30, 5), y_test:(30,)
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=None,
#               importance_type='gain', interaction_constraints=None,
#               learning_rate=0.0001, max_delta_step=0, max_depth=5,
#               min_child_weight=5, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=7, nthread=None, num_parallel_tree=None,
#               objective='multi:softprob', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=None, subsample=1,
#               tree_method=None, validate_parameters=False, verbosity=1)
# [0]#011validation_0-mlogloss:1.09853#011validation_1-mlogloss:1.09853
# Multiple eval metrics have been passed: 'validation_1-mlogloss' will be used for early stopping.
#
# Will train until validation_1-mlogloss hasn't improved in 10 rounds.
# [1]#011validation_0-mlogloss:1.09845#011validation_1-mlogloss:1.09845
# [2]#011validation_0-mlogloss:1.09838#011validation_1-mlogloss:1.09837
# [3]#011validation_0-mlogloss:1.09830#011validation_1-mlogloss:1.09829
# [4]#011validation_0-mlogloss:1.09822#011validation_1-mlogloss:1.09821
# [5]#011validation_0-mlogloss:1.09814#011validation_1-mlogloss:1.09812
# [6]#011validation_0-mlogloss:1.09806#011validation_1-mlogloss:1.09804
# [7]#011validation_0-mlogloss:1.09798#011validation_1-mlogloss:1.09796
# [8]#011validation_0-mlogloss:1.09790#011validation_1-mlogloss:1.09788
# [9]#011validation_0-mlogloss:1.09782#011validation_1-mlogloss:1.09780
# [10]#011validation_0-mlogloss:1.09774#011validation_1-mlogloss:1.09772
# [11]#011validation_0-mlogloss:1.09767#011validation_1-mlogloss:1.09763
# [12]#011validation_0-mlogloss:1.09759#011validation_1-mlogloss:1.09755
# [13]#011validation_0-mlogloss:1.09751#011validation_1-mlogloss:1.09747
# [14]#011validation_0-mlogloss:1.09743#011validation_1-mlogloss:1.09739
# [15]#011validation_0-mlogloss:1.09735#011validation_1-mlogloss:1.09731
# [16]#011validation_0-mlogloss:1.09727#011validation_1-mlogloss:1.09723
# [17]#011validation_0-mlogloss:1.09719#011validation_1-mlogloss:1.09715
# [18]#011validation_0-mlogloss:1.09712#011validation_1-mlogloss:1.09706
# [19]#011validation_0-mlogloss:1.09704#011validation_1-mlogloss:1.09698
# [20]#011validation_0-mlogloss:1.09696#011validation_1-mlogloss:1.09690
# [21]#011validation_0-mlogloss:1.09688#011validation_1-mlogloss:1.09682
# [22]#011validation_0-mlogloss:1.09680#011validation_1-mlogloss:1.09674
# [23]#011validation_0-mlogloss:1.09672#011validation_1-mlogloss:1.09666
# [24]#011validation_0-mlogloss:1.09664#011validation_1-mlogloss:1.09658
# [25]#011validation_0-mlogloss:1.09657#011validation_1-mlogloss:1.09650
# [26]#011validation_0-mlogloss:1.09649#011validation_1-mlogloss:1.09641
# [27]#011validation_0-mlogloss:1.09641#011validation_1-mlogloss:1.09633
# [28]#011validation_0-mlogloss:1.09633#011validation_1-mlogloss:1.09625
# [29]#011validation_0-mlogloss:1.09625#011validation_1-mlogloss:1.09617
# [30]#011validation_0-mlogloss:1.09617#011validation_1-mlogloss:1.09609
# [31]#011validation_0-mlogloss:1.09609#011validation_1-mlogloss:1.09601
# [32]#011validation_0-mlogloss:1.09601#011validation_1-mlogloss:1.09593
# [33]#011validation_0-mlogloss:1.09594#011validation_1-mlogloss:1.09585
# [34]#011validation_0-mlogloss:1.09586#011validation_1-mlogloss:1.09577
# [35]#011validation_0-mlogloss:1.09578#011validation_1-mlogloss:1.09569
# [36]#011validation_0-mlogloss:1.09570#011validation_1-mlogloss:1.09560
# [37]#011validation_0-mlogloss:1.09562#011validation_1-mlogloss:1.09552
# [38]#011validation_0-mlogloss:1.09554#011validation_1-mlogloss:1.09544
# [39]#011validation_0-mlogloss:1.09547#011validation_1-mlogloss:1.09536
# [40]#011validation_0-mlogloss:1.09539#011validation_1-mlogloss:1.09528
# [41]#011validation_0-mlogloss:1.09531#011validation_1-mlogloss:1.09520
# [42]#011validation_0-mlogloss:1.09523#011validation_1-mlogloss:1.09512
# [43]#011validation_0-mlogloss:1.09515#011validation_1-mlogloss:1.09504
# [44]#011validation_0-mlogloss:1.09507#011validation_1-mlogloss:1.09495
# [45]#011validation_0-mlogloss:1.09499#011validation_1-mlogloss:1.09487
# [46]#011validation_0-mlogloss:1.09492#011validation_1-mlogloss:1.09479
# [47]#011validation_0-mlogloss:1.09484#011validation_1-mlogloss:1.09471
# [48]#011validation_0-mlogloss:1.09476#011validation_1-mlogloss:1.09463
# [49]#011validation_0-mlogloss:1.09468#011validation_1-mlogloss:1.09455
# [50]#011validation_0-mlogloss:1.09460#011validation_1-mlogloss:1.09447
# [51]#011validation_0-mlogloss:1.09452#011validation_1-mlogloss:1.09439
# [52]#011validation_0-mlogloss:1.09445#011validation_1-mlogloss:1.09431
# [53]#011validation_0-mlogloss:1.09437#011validation_1-mlogloss:1.09423
# [54]#011validation_0-mlogloss:1.09429#011validation_1-mlogloss:1.09414
# [55]#011validation_0-mlogloss:1.09421#011validation_1-mlogloss:1.09406
# [56]#011validation_0-mlogloss:1.09413#011validation_1-mlogloss:1.09398
# [57]#011validation_0-mlogloss:1.09405#011validation_1-mlogloss:1.09390
# [58]#011validation_0-mlogloss:1.09398#011validation_1-mlogloss:1.09382
# [59]#011validation_0-mlogloss:1.09390#011validation_1-mlogloss:1.09374
# [60]#011validation_0-mlogloss:1.09382#011validation_1-mlogloss:1.09366
# [61]#011validation_0-mlogloss:1.09374#011validation_1-mlogloss:1.09358
# [62]#011validation_0-mlogloss:1.09366#011validation_1-mlogloss:1.09350
# [63]#011validation_0-mlogloss:1.09359#011validation_1-mlogloss:1.09342
# [64]#011validation_0-mlogloss:1.09351#011validation_1-mlogloss:1.09334
# [65]#011validation_0-mlogloss:1.09343#011validation_1-mlogloss:1.09326
# [66]#011validation_0-mlogloss:1.09335#011validation_1-mlogloss:1.09318
# [67]#011validation_0-mlogloss:1.09327#011validation_1-mlogloss:1.09309
# [68]#011validation_0-mlogloss:1.09319#011validation_1-mlogloss:1.09301
# [69]#011validation_0-mlogloss:1.09312#011validation_1-mlogloss:1.09293
# [70]#011validation_0-mlogloss:1.09304#011validation_1-mlogloss:1.09285
# [71]#011validation_0-mlogloss:1.09296#011validation_1-mlogloss:1.09277
# [72]#011validation_0-mlogloss:1.09288#011validation_1-mlogloss:1.09269
# [73]#011validation_0-mlogloss:1.09280#011validation_1-mlogloss:1.09261
# [74]#011validation_0-mlogloss:1.09273#011validation_1-mlogloss:1.09253
# [75]#011validation_0-mlogloss:1.09265#011validation_1-mlogloss:1.09245
# [76]#011validation_0-mlogloss:1.09257#011validation_1-mlogloss:1.09237
# [77]#011validation_0-mlogloss:1.09249#011validation_1-mlogloss:1.09229
# [78]#011validation_0-mlogloss:1.09241#011validation_1-mlogloss:1.09221
# [79]#011validation_0-mlogloss:1.09234#011validation_1-mlogloss:1.09213
# [80]#011validation_0-mlogloss:1.09226#011validation_1-mlogloss:1.09205
# [81]#011validation_0-mlogloss:1.09218#011validation_1-mlogloss:1.09197
# [82]#011validation_0-mlogloss:1.09210#011validation_1-mlogloss:1.09188
# [83]#011validation_0-mlogloss:1.09202#011validation_1-mlogloss:1.09180
# [84]#011validation_0-mlogloss:1.09195#011validation_1-mlogloss:1.09172
# [85]#011validation_0-mlogloss:1.09187#011validation_1-mlogloss:1.09164
# [86]#011validation_0-mlogloss:1.09179#011validation_1-mlogloss:1.09156
# [87]#011validation_0-mlogloss:1.09171#011validation_1-mlogloss:1.09148
# [88]#011validation_0-mlogloss:1.09163#011validation_1-mlogloss:1.09140
# [89]#011validation_0-mlogloss:1.09156#011validation_1-mlogloss:1.09132
# [90]#011validation_0-mlogloss:1.09148#011validation_1-mlogloss:1.09124
# [91]#011validation_0-mlogloss:1.09140#011validation_1-mlogloss:1.09116
# [92]#011validation_0-mlogloss:1.09132#011validation_1-mlogloss:1.09108
# [93]#011validation_0-mlogloss:1.09125#011validation_1-mlogloss:1.09100
# [94]#011validation_0-mlogloss:1.09117#011validation_1-mlogloss:1.09092
# [95]#011validation_0-mlogloss:1.09109#011validation_1-mlogloss:1.09084
# [96]#011validation_0-mlogloss:1.09101#011validation_1-mlogloss:1.09076
# [97]#011validation_0-mlogloss:1.09093#011validation_1-mlogloss:1.09068
# [98]#011validation_0-mlogloss:1.09086#011validation_1-mlogloss:1.09060
# [99]#011validation_0-mlogloss:1.09078#011validation_1-mlogloss:1.09052
#               precision    recall  f1-score   support
#
#            0       1.00      0.92      0.96        12
#            1       0.86      1.00      0.92         6
#            2       1.00      1.00      1.00        12
#
#     accuracy                           0.97        30
#    macro avg       0.95      0.97      0.96        30
# weighted avg       0.97      0.97      0.97        30
#
# [[11  1  0]
#  [ 0  6  0]
#  [ 0  0 12]]
# 0.9714285714285714
# save booster
#
# 2020-08-20 06:45:09 Completed - Training job completed
# Training seconds: 55
# Billable seconds: 55

# %%
job_name = xgb_estimator.latest_training_job.name

# %%
from sagemaker.analytics import TrainingJobAnalytics

metric_name = 'validation:rmse'  # validation_1-mlogloss
metric_name = 'mlogloss'
metrics_dataframe = TrainingJobAnalytics(training_job_name=job_name, metric_names=[metric_name]).dataframe()
# Out:
# Warning: No metrics called mlogloss found
